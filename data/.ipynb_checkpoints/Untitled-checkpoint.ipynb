# %%
# Import Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy import stats
from pprint import pprint

# %% [markdown]
# Read in all CSV files

# %%
# Read in departments CSV file
departments_df = pd.read_csv("departments.csv")
departments_df.tail()
# Out:
#   dept_no           dept_name
# 4    d005         Development
# 5    d006  Quality Management
# 6    d007               Sales
# 7    d008            Research
# 8    d009    Customer Service

# %%
#### Read in dept_emp CSV file
dept_emp_df = pd.read_csv("dept_emp.csv")
dept_emp_df.tail()
# Out:
#         emp_no dept_no
# 331598  499995    d004
# 331599  499996    d004
# 331600  499997    d005
# 331601  499998    d002
# 331602  499999    d004

# %%
# Read in dept_manager CSV file
dept_manager_df = pd.read_csv("dept_manager.csv")
dept_manager_df.head()
# Out:
#   dept_no  emp_no
# 0    d001  110022
# 1    d001  110039
# 2    d002  110085
# 3    d002  110114
# 4    d003  110183

# %%
# Read in employees CSV file
employees_df = pd.read_csv('employees.csv')
employees_df.head()
# Out:
#    emp_no emp_title_id  birth_date  first_name  last_name sex   hire_date
# 0  473302        s0001   7/25/1953    Hideyuki   Zallocco   M   4/28/1990
# 1  475053        e0002  11/18/1954       Byong  Delgrande   F    9/7/1991
# 2   57444        e0002   1/30/1958       Berry       Babb   F   3/21/1992
# 3  421786        s0001   9/28/1957       Xiong   Verhoeff   M  11/26/1987
# 4  282238        e0003  10/28/1952  Abdelkader    Baumann   F   1/18/1991

# %%
# Read in salaries CSV file
salaries_df = pd.read_csv("salaries.csv")
salaries_df.head()
# Out:
#    emp_no  salary
# 0   10001   60117
# 1   10002   65828
# 2   10003   40006
# 3   10004   40054
# 4   10005   78228

# %%
# Read in title CSV file
title_df = pd.read_csv("titles.csv")
title_df.head()
# Out:
#   title_id               title
# 0    s0001               Staff
# 1    s0002        Senior Staff
# 2    e0001  Assistant Engineer
# 3    e0002            Engineer
# 4    e0003     Senior Engineer

# %%
# Rename column to ease merging
title_df = title_df.rename(columns={"title_id":"emp_title_id",
                                    "title":"title"})

# %%
title_df
# Out:
#   emp_title_id               title
# 0        s0001               Staff
# 1        s0002        Senior Staff
# 2        e0001  Assistant Engineer
# 3        e0002            Engineer
# 4        e0003     Senior Engineer
# 5        e0004    Technique Leader
# 6        m0001             Manager

# %% [markdown]
# Merging department DataFrames

# %%
# Merge departments_df, dept_emp_df, on dept_no
dept_merged_df = pd.merge(departments_df, dept_emp_df, on = ["dept_no"])
dept_merged_df
# Out:
#        dept_no         dept_name  emp_no
# 0         d001         Marketing   10017
# 1         d001         Marketing   10055
# 2         d001         Marketing   10058
# 3         d001         Marketing   10108
# 4         d001         Marketing   10140
# ...        ...               ...     ...
# 331598    d009  Customer Service  499965
# 331599    d009  Customer Service  499978
# 331600    d009  Customer Service  499982
# 331601    d009  Customer Service  499983
# 331602    d009  Customer Service  499991
#
# [331603 rows x 3 columns]

# %%
employee_info_df = pd.merge(employees_df, dept_merged_df, on =["emp_no"])
employee_info_df
# Out:
#         emp_no emp_title_id  birth_date  first_name  last_name sex  \
# 0       473302        s0001   7/25/1953    Hideyuki   Zallocco   M
# 1       475053        e0002  11/18/1954       Byong  Delgrande   F
# 2        57444        e0002   1/30/1958       Berry       Babb   F
# 3       421786        s0001   9/28/1957       Xiong   Verhoeff   M
# 4       282238        e0003  10/28/1952  Abdelkader    Baumann   F
# ...        ...          ...         ...         ...        ...  ..
# 331598  255832        e0002    5/8/1955      Yuping     Dayang   F
# 331599   76671        s0001    6/9/1959      Ortrud   Plessier   M
# 331600  264920        s0001   9/22/1959       Percy   Samarati   F
# 331601  264920        s0001   9/22/1959       Percy   Samarati   F
# 331602  464503        s0002   5/31/1964      Arvind  Slobodova   M
#
#          hire_date dept_no           dept_name
# 0        4/28/1990    d002             Finance
# 1         9/7/1991    d004          Production
# 2        3/21/1992    d004          Production
# 3       11/26/1987    d003     Human Resources
# 4        1/18/1991    d006  Quality Management
# ...            ...     ...                 ...
# 331598   2/26/1995    d004          Production
# 331599   2/24/1988    d007               Sales
# 331600    9/8/1994    d002             Finance
# 331601    9/8/1994    d007               Sales
# 331602  11/23/1987    d008            Research
#
# [331603 rows x 9 columns]

# %%
 # Merge dept_merged_df with dept_manager_df on emp_no
employee_salary_df = pd.merge(employee_info_df, salaries_df, on = ["emp_no"])
employee_salary_df
# Out:
#         emp_no emp_title_id  birth_date  first_name  last_name sex  \
# 0       473302        s0001   7/25/1953    Hideyuki   Zallocco   M
# 1       475053        e0002  11/18/1954       Byong  Delgrande   F
# 2        57444        e0002   1/30/1958       Berry       Babb   F
# 3       421786        s0001   9/28/1957       Xiong   Verhoeff   M
# 4       282238        e0003  10/28/1952  Abdelkader    Baumann   F
# ...        ...          ...         ...         ...        ...  ..
# 331598  255832        e0002    5/8/1955      Yuping     Dayang   F
# 331599   76671        s0001    6/9/1959      Ortrud   Plessier   M
# 331600  264920        s0001   9/22/1959       Percy   Samarati   F
# 331601  264920        s0001   9/22/1959       Percy   Samarati   F
# 331602  464503        s0002   5/31/1964      Arvind  Slobodova   M
#
#          hire_date dept_no           dept_name  salary
# 0        4/28/1990    d002             Finance   40000
# 1         9/7/1991    d004          Production   53422
# 2        3/21/1992    d004          Production   48973
# 3       11/26/1987    d003     Human Resources   40000
# 4        1/18/1991    d006  Quality Management   40000
# ...            ...     ...                 ...     ...
# 331598   2/26/1995    d004          Production   75355
# 331599   2/24/1988    d007               Sales   61886
# 331600    9/8/1994    d002             Finance   62772
# 331601    9/8/1994    d007               Sales   62772
# 331602  11/23/1987    d008            Research   41708
#
# [331603 rows x 10 columns]

# %% [markdown]
# Merge titles and manger to DataFrames

# %%
# Merge employees and salaries on emp_no
final_employee_df = pd.merge(employee_salary_df, title_df, on = ["emp_title_id"])
final_employee_df
# Out:
#         emp_no emp_title_id  birth_date  first_name   last_name sex  \
# 0       473302        s0001   7/25/1953    Hideyuki    Zallocco   M
# 1       421786        s0001   9/28/1957       Xiong    Verhoeff   M
# 2       273487        s0001   4/14/1957   Christoph     Parfitt   M
# 3       246449        s0001   3/23/1958       Subbu  Bultermann   F
# 4        48085        s0001   1/19/1964  Venkatesan        Gilg   M
# ...        ...          ...         ...         ...         ...  ..
# 331598  111400        m0001   11/9/1959        Arie     Staelin   M
# 331599  111133        m0001   3/16/1955       Hauke       Zhang   M
# 331600  110085        m0001  10/28/1959        Ebru       Alpin   M
# 331601  110386        m0001   10/4/1953        Shem      Kieras   M
# 331602  111784        m0001   6/14/1956       Marjo  Giarratana   F
#
#          hire_date dept_no         dept_name  salary    title
# 0        4/28/1990    d002           Finance   40000    Staff
# 1       11/26/1987    d003   Human Resources   40000    Staff
# 2        6/28/1991    d003   Human Resources   56087    Staff
# 3        3/25/1988    d007             Sales   87084    Staff
# 4        6/28/1993    d002           Finance   63016    Staff
# ...            ...     ...               ...     ...      ...
# 331598    1/1/1985    d008          Research   72446  Manager
# 331599  12/30/1986    d007             Sales   71148  Manager
# 331600    1/1/1985    d002           Finance   60026  Manager
# 331601  10/14/1988    d004        Production   40000  Manager
# 331602   2/12/1988    d009  Customer Service   40000  Manager
#
# [331603 rows x 11 columns]

# %% [markdown]
# Final Merging of the big DataFrames

# %%
#list the employee number, last name, first name, sex and salary of each employee
emp_list_df = final_employee_df.loc[:,['emp_no', 'last_name', 'first_name', 'sex', 'salary']]
emp_list_df.head()
# Out:
#    emp_no   last_name  first_name sex  salary
# 0  473302    Zallocco    Hideyuki   M   40000
# 1  421786    Verhoeff       Xiong   M   40000
# 2  273487     Parfitt   Christoph   M   56087
# 3  246449  Bultermann       Subbu   F   87084
# 4   48085        Gilg  Venkatesan   M   63016

# %%
# Employees who were hired in 1986
#hire1986_df = (final_employee_df["hire_date"] > "1/1/1986") & (emp_info_df["hire_date"] <= "12/31/1986")
#hire_df = final_employee_df.loc[hire1986_df]
#hire_df
#hire1986_df
hire1986_df = final_employee_df.loc[final_employee_df['hire_date'].between("1/1/1986", "12/31/1986")]
hire1986_df
# Out:
#         emp_no emp_title_id  birth_date first_name   last_name sex  \
# 1       421786        s0001   9/28/1957      Xiong    Verhoeff   M
# 9       280408        s0001   9/19/1964    Elliott        Perl   M
# 15      289261        s0001    2/4/1958        Gad    Nollmann   M
# 17      299898        s0001   2/15/1964   Munehiko     Janocha   M
# 29       21620        s0001  11/24/1960    Shaowen    Pramanik   M
# ...        ...          ...         ...        ...         ...  ..
# 331587  110567        m0001   4/25/1964       Leon    DasSarma   F
# 331590  110114        m0001   3/28/1957      Isamu  Legleitner   F
# 331596  110344        m0001    9/7/1961     Rosine       Cools   F
# 331599  111133        m0001   3/16/1955      Hauke       Zhang   M
# 331601  110386        m0001   10/4/1953       Shem      Kieras   M
#
#          hire_date dept_no        dept_name  salary    title
# 1       11/26/1987    d003  Human Resources   40000    Staff
# 9       10/29/1987    d007            Sales   75963    Staff
# 15       10/1/1985    d007            Sales   63068    Staff
# 17      12/11/1988    d001        Marketing   63315    Staff
# 29      12/27/1992    d008         Research   40000    Staff
# ...            ...     ...              ...     ...      ...
# 331587  10/21/1986    d005      Development   40000  Manager
# 331590   1/14/1985    d002          Finance   52070  Manager
# 331596  11/22/1985    d004       Production   50365  Manager
# 331599  12/30/1986    d007            Sales   71148  Manager
# 331601  10/14/1988    d004       Production   40000  Manager
#
# [101225 rows x 11 columns]

# %%
# List the manager of each department with the following informatiom: department number, department name,
# the manager's employee number, last name, first name.
department_manager_df = final_employee_df.loc[final_employee_df["title"]=="Manager"]
department_manager_df
#department_manager_df2 =department_manager_df.loc[:,["dept_no", "dept_name", "emp_no", "last_name", "first_name"]]
#department_manager_df2
# Out:
#         emp_no emp_title_id  birth_date   first_name     last_name sex  \
# 331579  111877        m0001  10/18/1962      Xiaobin      Spinelli   F
# 331580  111534        m0001   6/27/1952       Hilary        Kambil   F
# 331581  110765        m0001   5/22/1954       Rutger       Hofmeyr   F
# 331582  110420        m0001   7/27/1963        Oscar      Ghazalie   M
# 331583  110725        m0001   3/14/1961    Peternela       Onuegbe   F
# 331584  110022        m0001   9/12/1956    Margareta    Markovitch   M
# 331585  111035        m0001   2/24/1962  Przemyslawa     Kaelbling   M
# 331586  110511        m0001    7/8/1957     DeForest      Hagimont   M
# 331587  110567        m0001   4/25/1964         Leon      DasSarma   F
# 331588  110183        m0001   6/24/1953      Shirish  Ossenbruggen   F
# 331589  111939        m0001   3/25/1960      Yuchang       Weedman   M
# 331590  110114        m0001   3/28/1957        Isamu    Legleitner   F
# 331591  110854        m0001   8/19/1960         Dung         Pesch   M
# 331592  110039        m0001   6/21/1963     Vishwani      Minakawa   M
# 331593  110800        m0001    2/7/1963       Sanjoy       Quadeer   F
# 331594  110228        m0001   12/2/1958      Karsten       Sigstam   F
# 331595  110303        m0001    6/8/1956    Krassimir       Wegerle   F
# 331596  110344        m0001    9/7/1961       Rosine         Cools   F
# 331597  111692        m0001   10/5/1954        Tonny   Butterworth   F
# 331598  111400        m0001   11/9/1959         Arie       Staelin   M
# 331599  111133        m0001   3/16/1955        Hauke         Zhang   M
# 331600  110085        m0001  10/28/1959         Ebru         Alpin   M
# 331601  110386        m0001   10/4/1953         Shem        Kieras   M
# 331602  111784        m0001   6/14/1956        Marjo    Giarratana   F
#
#          hire_date dept_no           dept_name  salary    title
# 331579   8/17/1991    d009    Customer Service   53846  Manager
# 331580   1/31/1988    d008            Research   48077  Manager
# 331581    1/7/1989    d006  Quality Management   40055  Manager
# 331582    2/5/1992    d004          Production   40000  Manager
# 331583    1/1/1985    d006  Quality Management   61357  Manager
# 331584    1/1/1985    d001           Marketing   71166  Manager
# 331585    1/1/1985    d007               Sales   71612  Manager
# 331586    1/1/1985    d005         Development   48626  Manager
# 331587  10/21/1986    d005         Development   40000  Manager
# 331588    1/1/1985    d003     Human Resources   48291  Manager
# 331589   7/10/1989    d009    Customer Service   40000  Manager
# 331590   1/14/1985    d002             Finance   52070  Manager
# 331591    6/9/1989    d006  Quality Management   45169  Manager
# 331592   4/12/1986    d001           Marketing   69941  Manager
# 331593   8/12/1986    d006  Quality Management   50457  Manager
# 331594    8/4/1985    d003     Human Resources   40000  Manager
# 331595    1/1/1985    d004          Production   42093  Manager
# 331596  11/22/1985    d004          Production   50365  Manager
# 331597    1/1/1985    d009    Customer Service   40000  Manager
# 331598    1/1/1985    d008            Research   72446  Manager
# 331599  12/30/1986    d007               Sales   71148  Manager
# 331600    1/1/1985    d002             Finance   60026  Manager
# 331601  10/14/1988    d004          Production   40000  Manager
# 331602   2/12/1988    d009    Customer Service   40000  Manager

# %%
department_manager_df2 =department_manager_df.iloc[:,[7, 9, 0, 4,3]]
department_manager_df2
# Out:
#        dept_no  salary  emp_no     last_name   first_name
# 331579    d009   53846  111877      Spinelli      Xiaobin
# 331580    d008   48077  111534        Kambil       Hilary
# 331581    d006   40055  110765       Hofmeyr       Rutger
# 331582    d004   40000  110420      Ghazalie        Oscar
# 331583    d006   61357  110725       Onuegbe    Peternela
# 331584    d001   71166  110022    Markovitch    Margareta
# 331585    d007   71612  111035     Kaelbling  Przemyslawa
# 331586    d005   48626  110511      Hagimont     DeForest
# 331587    d005   40000  110567      DasSarma         Leon
# 331588    d003   48291  110183  Ossenbruggen      Shirish
# 331589    d009   40000  111939       Weedman      Yuchang
# 331590    d002   52070  110114    Legleitner        Isamu
# 331591    d006   45169  110854         Pesch         Dung
# 331592    d001   69941  110039      Minakawa     Vishwani
# 331593    d006   50457  110800       Quadeer       Sanjoy
# 331594    d003   40000  110228       Sigstam      Karsten
# 331595    d004   42093  110303       Wegerle    Krassimir
# 331596    d004   50365  110344         Cools       Rosine
# 331597    d009   40000  111692   Butterworth        Tonny
# 331598    d008   72446  111400       Staelin         Arie
# 331599    d007   71148  111133         Zhang        Hauke
# 331600    d002   60026  110085         Alpin         Ebru
# 331601    d004   40000  110386        Kieras         Shem
# 331602    d009   40000  111784    Giarratana        Marjo

# %%
# List the department number for each employee along with employee's employee number, last name
# first name, and department name
each_employee_df = final_employee_df.loc[:, ["dept_no", "emp_no", "last_name", "first_name", "dept_name"]]
each_employee_df
# Out:
#        dept_no  emp_no   last_name  first_name         dept_name
# 0         d002  473302    Zallocco    Hideyuki           Finance
# 1         d003  421786    Verhoeff       Xiong   Human Resources
# 2         d003  273487     Parfitt   Christoph   Human Resources
# 3         d007  246449  Bultermann       Subbu             Sales
# 4         d002   48085        Gilg  Venkatesan           Finance
# ...        ...     ...         ...         ...               ...
# 331598    d008  111400     Staelin        Arie          Research
# 331599    d007  111133       Zhang       Hauke             Sales
# 331600    d002  110085       Alpin        Ebru           Finance
# 331601    d004  110386      Kieras        Shem        Production
# 331602    d009  111784  Giarratana       Marjo  Customer Service
#
# [331603 rows x 5 columns]

# %%
# List first name, last name, and sex of each employee whose first name is Hercules and whose last name begins 
# with latter B
first_Hercules_df = final_employee_df.loc[(final_employee_df['first_name']== 'Hercules') & (final_employee_df['last_name'] =='*B*')]
first_Hercules_df
# Out:
# Empty DataFrame
# Columns: [emp_no, emp_title_id, birth_date, first_name, last_name, sex, hire_date, dept_no, dept_name, salary, title]
# Index: []
